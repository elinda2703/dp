# %%
import tools
import importlib

from scipy.sparse.linalg import spsolve
import geopandas as gpd
import pandas as pd
import numpy as np
#from libpysal.weights import Queen, Rook
import matplotlib.pyplot as plt
from esda.moran import Moran
#from shapely.geometry import Polygon
#import copy
import seaborn as sns
from libpysal import graph,weights
#from splot.libpysal import plot_spatial_weights
#from scipy.sparse import spmatrix, triu, diags, coo_array

#from spreg import ML_Error
importlib.reload(tools)
from math import sqrt
import warnings

# Only ignore the annoying "update" and "user" warnings
warnings.filterwarnings('ignore')

# %%
sizes = [400,100,25]
rhos = np.arange(-0.9, 1.0, 0.1)
n_runs = 10
shapes = ["square","pent","hex"]

# %%
n_corrupt = 10                            # number of corruption replicates

# %%
shape = "square"
for size in sizes:
    gdf = generate_square_lattice(sqrt(size))
    
    
    g_rook = build_g_rook(gdf)
    g_rook.to_parquet(f"graphs/{shape}/size_{size}/g_true.parquet")
    
    gdf['region'] = gdf.index.map(regions_dict[f'reg{size}'])
    simulate_autocorrelated_data(gdf,g_rook.transform('R').sparse,rhos,n_runs)
    gdf.to_parquet(f"data/autocorrelation/gdf_{shape}_{size}.parquet")
    
    g_borders,border_remains = build_g_borders(gdf,g_rook)
    g_center_region,center_remains = build_g_region(gdf,g_rook,'center')
    g_periphery_region,periphery_remains = build_g_region(gdf,g_rook,'periphery')
    
    
    create_corrupted_graphs(g_rook,n_corrupt,perc_missing,shape,size,'random')
    create_corrupted_graphs(g_rook,n_corrupt,perc_missing,shape,size,'border',border_remains)
    create_corrupted_graphs(g_rook,n_corrupt,perc_missing,shape,size,'center',center_remains)
    create_corrupted_graphs(g_rook,n_corrupt,perc_missing,shape,size,'periphery',periphery_remains)

# %%
g_rook.plot(pent_gdfs[25])
# Out:
# <Axes: >

# %%
gdf = gpd.read_parquet('data\gdf_pent_25.parquet')
ax = gdf.plot(column='region', categorical=True, legend=True, edgecolor='black', cmap='Set2', figsize=(10, 10))
gdf.apply(lambda x: ax.annotate(text=x.name, xy=x.geometry.centroid.coords[0], ha='center', va='center'), axis=1)
ax.set_axis_off()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\elapo\AppData\Local\Temp\ipykernel_23956\2850745717.py:1: SyntaxWarning: invalid escape sequence '\g'
#   gdf = gpd.read_parquet('data\gdf_pent_25.parquet')

# %%
gb = graph.Graph.build_block_contiguity(gdf['region'])
gr = graph.Graph.build_contiguity(gdf,rook=True)
gd = gr.difference(gb)
gi = gr.intersection(gb)

ids_in_a = gdf[gdf['region'] == 'A'].index

gs = gr.subgraph(ids_in_a)
gi.plot(gdf)
# Out:
# <Axes: >

# %%
edges_df = gr.adjacency.reset_index()
# 3. Create a filter: Keep rows where EITHER 'focal' OR 'neighbor' is in Region A
mask = edges_df['focal'].isin(ids_in_a) | edges_df['neighbor'].isin(ids_in_a)

# 4. Apply the filter to get your final list of edges
edges_touching_a = edges_df[mask]
g_touching_a = graph.Graph.from_adjacency(edges_touching_a,'focal','neighbor','weight')
g_touching_a.plot(gdf)
# Out:
# <Axes: >

# %%
for shape in shapes:
    for size in sizes:
        g_true = graph.read_parquet(f"graphs/{shape}/size_{size}/g_true.parquet")
        W_sparse = g_true.to_W().sparse
        for n in range(n_corrupt):
            W = W_sparse.copy()
            iteration = 0
            while True:
                W, success = tools.remove_one_edge(W, method='no_isolates')
                if not success:
                    break
                iteration += 1
                corrupted_g = graph.Graph.from_sparse(W)
                corrupted_g.to_parquet(
                    f"graphs/{shape}/size_{size}/no_isolates/random/g_missing{iteration}_run{n}.parquet")

# %%
for shape in shapes:
    for size in [100,400]:
        g_true = graph.read_parquet(f"graphs/{shape}/size_{size}/g_true.parquet")
        W_sparse = g_true.to_W().sparse
        for n in range(n_corrupt):
            W = W_sparse.copy()
            iteration = 0
            while True:
                W, success = tools.remove_one_edge(W, method='mst',max_components = 1)
                if not success:
                    break
                iteration += 1
                corrupted_g = graph.Graph.from_sparse(W)
                corrupted_g.to_parquet(
                    f"graphs/{shape}/size_{size}/one_component/random/g_missing{iteration}_run{n}.parquet")

# %%
for shape in shapes:
    for size in [100, 400]:
        gdf = gpd.read_parquet(f"data/regionalization/gdf_{shape}_{size}.parquet")
        g_true = graph.read_parquet(f"graphs/{shape}/size_{size}/g_true.parquet")
        W_sparse = g_true.to_W().sparse
        for n in range(n_corrupt):
            region_col = f"zone_id_{n}"

            # ── borders ──────────────────────────────────────────────────────
            g_borders, _ = tools.build_g_borders(gdf, g_true, region_col=region_col)
            border_edges = tools.graph_to_edge_set(g_borders, g_true.unique_ids)
            for condition, kwargs in [
                ("one_component", dict(method='mst', max_components=1)),
                ("no_isolates",   dict(method='no_isolates')),
            ]:
                corrupted_graphs = tools.run_corruption_loop(
                    W_sparse, candidate_edges=border_edges, **kwargs
                )
                for i, corrupted_g in enumerate(corrupted_graphs, start=1):
                    corrupted_g.to_parquet(
                        f"graphs/{shape}/size_{size}/{condition}/borders/g_missing{i}_run{n}.parquet"
                    )

            # ── local ────────────────────────────────────────────────────────
            region_id = np.random.choice(gdf[region_col].unique())
            g_region, _ = tools.build_g_region(gdf, g_true, region_col=region_col, region_id=region_id)
            local_edges = tools.graph_to_edge_set(g_region, g_true.unique_ids)
            for condition, kwargs in [
                ("one_component", dict(method='mst', max_components=1)),
                ("no_isolates",   dict(method='no_isolates')),
            ]:
                corrupted_graphs = tools.run_corruption_loop(
                    W_sparse, candidate_edges=local_edges, **kwargs
                )
                for i, corrupted_g in enumerate(corrupted_graphs, start=1):
                    corrupted_g.to_parquet(
                        f"graphs/{shape}/size_{size}/{condition}/local/g_missing{i}_run{n}.parquet"
                    )

# %%
g = graph.read_parquet("graphs/square/size_400/one_component/local/g_missing17_run2.parquet")
gdf = gpd.read_parquet(f"data/regionalization/gdf_{"square"}_{400}.parquet")

# %%
tools.plot_graph(gdf,g)

# %%
for size in sizes:
    for shape in shapes:
        gdf = gpd.read_parquet(f"data/gdf_{shape}_{size}.parquet")
        gdf.plot(color='white', edgecolor='black',figsize=(5, 5))
        plt.axis("off")
        plt.savefig(f"empty_{square}_{size}.svg",bbox_inches = 'tight')

# %%
gdf = gpd.read_parquet(f"data/gdf_square_25.parquet")
g_true = graph.read_parquet("graphs/square/size_25/g_true.parquet")
half_missing = graph.read_parquet("graphs/square/size_25/no_isolates/g_missing9_run9.parquet")
most_missing = graph.read_parquet("graphs/square/size_25/no_isolates/g_missing18_run9.parquet")

# %%
gdf = gpd.read_parquet(f"data/gdf_square_25.parquet")
g_true = graph.read_parquet("graphs/square/size_25/g_true.parquet")
half_missing_mst = graph.read_parquet("graphs/square/size_25/max_components/g_missing9_run9.parquet")
most_missing_mst = graph.read_parquet("graphs/square/size_25/max_components/g_missing15_run9.parquet")

# %%
gdf = gpd.read_parquet("data/regionalization/gdf_square_100.parquet")
g_true = graph.read_parquet("graphs/square/size_100/g_true.parquet")
half_missing_mst = graph.read_parquet("graphs/square/size_100/max_components/g_missing9_run9.parquet")
most_missing_mst = graph.read_parquet("graphs/square/size_100/max_components/g_missing18_run5.parquet")

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
most_missing_mst.plot(gdf,color = 'red',ax=ax)
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(10.5), np.float64(-0.5), np.float64(10.5))

# %%
gdf = gpd.read_parquet("data/regionalization/gdf_square_100.parquet")
half_missing_mst = graph.read_parquet("graphs/square/size_100/mst/g_missing9_run9.parquet")
most_missing_mst = graph.read_parquet("graphs/square/size_100/mst/g_missing15_run9.parquet")

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
most_missing_mst.plot(gdf,color = 'red',ax=ax)
ax.axis("off")

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
most_missing_mst.plot(gdf,color = 'red',ax=ax)
ax.axis("off")
# Out:
# (np.float64(-0.25), np.float64(5.25), np.float64(-0.25), np.float64(5.25))

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
g_true.plot(gdf,color = 'red',ax=ax)
ax.axis("off")
fig.savefig("full.svg",bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
half_missing.plot(gdf,color = 'red',ax=ax)
ax.axis("off")
fig.savefig("half.svg",bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize=(5,5))
gdf.plot(ax=ax, color='white', edgecolor='black')
most_missing.plot(gdf,color = 'red',ax=ax)
ax.axis("off")
fig.savefig("most.svg",bbox_inches = 'tight')

# %%
square100.plot(column = "rho_0.9_run_2")
plt.axis("off")
plt.savefig("big_rho.png",bbox_inches = 'tight')

# %%
square100.plot(column = "rho_-0.0_run_9")
plt.axis("off")
plt.savefig("zero_rho.png",bbox_inches = 'tight')

# %%
square100.plot(column = "rho_-0.9_run_4")
plt.axis("off")
plt.savefig("small_rho.png",bbox_inches = 'tight')
